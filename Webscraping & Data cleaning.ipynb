# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# Base URL for RemoteOK engineer jobs
base_url = 'https://remoteok.com/remote-engineer-jobs'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'
}

job_list = []
page = 1  # Start from the first page
max_jobs = 200  # We want exactly 100 jobs

# Scrape until we collect 100 jobs
while len(job_list) < max_jobs:
    url = f"{base_url}?page={page}" if page > 1 else base_url
    print(f"Scraping page {page}: {url}")

    try:
        response = requests.get(url, headers=headers)
        if response.status_code != 200:
            print(f"Failed to fetch page {page}. Status code: {response.status_code}")
            break

        soup = BeautifulSoup(response.text, 'html.parser')
        jobs = soup.find_all('tr', class_='job')

        # Stop if no jobs found on the page
        if not jobs:
            print("No more jobs found.")
            break

        for job in jobs:
            # Stop if we've reached 100 jobs
            if len(job_list) >= max_jobs:
                break

            # Extract job data
            title_tag = job.find('h2', {'itemprop': 'title'})
            company_tag = job.find('h3', {'itemprop': 'name'})
            
            # Initialize metadata with default values
            location = 'N/A'
            salary = 'Not Listed'
            date_posted = 'N/A'
            
            # Parse location and salary from metadata
            metadata = job.find_all('div', class_='location')
            for meta in metadata:
                text = meta.text.strip().lower()
                if '$' in text:  # Salary field
                    salary = meta.text.strip()
                elif any(x in text for x in ['est', 'pst', 'cst', 'gmt', 'utc']):  # Timezone hints
                    continue  # Skip timezone info
                else:  # Location (could also be date in some cases)
                    location = meta.text.strip()
            
            # Try alternative ways to find the date
            # Method 1: Look for time tag
            time_tag = job.find('time')
            if time_tag:
                date_posted = time_tag.text.strip()
            else:
                # Method 2: Look for "X days ago" pattern in any element
                for elem in job.find_all(text=True):
                    if 'ago' in elem.lower():
                        date_posted = elem.strip()
                        break

            job_data = {
                'title': title_tag.text.strip() if title_tag else 'N/A',
                'company': company_tag.text.strip() if company_tag else 'N/A',
                'location': location,
                'salary': salary,
                'date_posted': date_posted
            }
            job_list.append(job_data)
            print(f"Collected job {len(job_list)}: {job_data['title']} | Posted: {job_data['date_posted']}")

        page += 1
        time.sleep(2)  # Be polite with the server

    except Exception as e:
        print(f"Error occurred: {e}")
        break

# Save exactly 100 jobs to CSV
with open('remote_jobs.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=['title', 'company', 'location', 'salary', 'date_posted'])
    writer.writeheader()
    writer.writerows(job_list[:max_jobs])  # Ensure we only save 100 jobs

print(f"\nSuccessfully saved {len(job_list[:max_jobs])} jobs to remote_jobs.csv")
# Out:
# Scraping page 1: https://remoteok.com/remote-engineer-jobs
# Collected job 1: Software Engineer | Posted: 1d
# Collected job 2: Senior Software Engineer KSPM | Posted: 1d
# Collected job 3: Software Engineer III | Posted: 1d
# Collected job 4: Back End Developer Winna.com | Posted: 9d
# Collected job 5: Software Engineer Infrastructure | Posted: 2d
# Collected job 6: Software Engineer Data | Posted: 2d
# Collected job 7: Software Engineer III Frontend | Posted: 2d
# Collected job 8: HQ Senior Frontend Engineer | Posted: 2d
# Collected job 9: Software Engineer Microservices | Posted: 2d
# Collected job 10: Senior Fullstack Engineer | Posted: 3d
# Collected job 11: Senior React Full stack Developer | Posted: 3d
# Collected job 12: Technical Product Manager Developer Platform | Posted: 3d
# Collected job 13: DevOps Engineer | Posted: 4d
# Collected job 14: Principal Software Engineer | Posted: 6d
# Collected job 15: Staff Backend Engineer | Posted: 7d
# Collected job 16: Software Engineer | Posted: 8d
# Collected job 17: Solidity Engineer Smart Contracts Engineer | Posted: 8d
# Collected job 18: Full Stack Engineer | Posted: 16d
# Collected job 19: Staff Software Engineer Metrics US | Posted: 10d
# Collected job 20: Kubernetes Engineer | Posted: 10d
# Scraping page 2: https://remoteok.com/remote-engineer-jobs?page=2
# Collected job 21: Software Engineer | Posted: 1d
# Collected job 22: Senior Software Engineer KSPM | Posted: 1d
# Collected job 23: Software Engineer III | Posted: 1d
# Collected job 24: Back End Developer Winna.com | Posted: 9d
# Collected job 25: Software Engineer Infrastructure | Posted: 2d
# Collected job 26: Software Engineer Data | Posted: 2d
# Collected job 27: Software Engineer III Frontend | Posted: 2d
# Collected job 28: HQ Senior Frontend Engineer | Posted: 2d
# Collected job 29: Software Engineer Microservices | Posted: 2d
# Collected job 30: Senior Fullstack Engineer | Posted: 3d
# Collected job 31: Senior React Full stack Developer | Posted: 3d
# Collected job 32: Technical Product Manager Developer Platform | Posted: 3d
# Collected job 33: DevOps Engineer | Posted: 4d
# Collected job 34: Principal Software Engineer | Posted: 6d
# Collected job 35: Staff Backend Engineer | Posted: 7d
# Collected job 36: Software Engineer | Posted: 8d
# Collected job 37: Solidity Engineer Smart Contracts Engineer | Posted: 8d
# Collected job 38: Full Stack Engineer | Posted: 16d
# Collected job 39: Staff Software Engineer Metrics US | Posted: 10d
# Collected job 40: Kubernetes Engineer | Posted: 10d
# Scraping page 3: https://remoteok.com/remote-engineer-jobs?page=3
# Collected job 41: Software Engineer | Posted: 1d
# Collected job 42: Senior Software Engineer KSPM | Posted: 1d
# Collected job 43: Software Engineer III | Posted: 1d
# Collected job 44: Back End Developer Winna.com | Posted: 9d
# Collected job 45: Software Engineer Infrastructure | Posted: 2d
# Collected job 46: Software Engineer Data | Posted: 2d
# Collected job 47: Software Engineer III Frontend | Posted: 2d
# Collected job 48: HQ Senior Frontend Engineer | Posted: 2d
# Collected job 49: Software Engineer Microservices | Posted: 2d
# Collected job 50: Senior Fullstack Engineer | Posted: 3d
# Collected job 51: Senior React Full stack Developer | Posted: 3d
# Collected job 52: Technical Product Manager Developer Platform | Posted: 3d
# Collected job 53: DevOps Engineer | Posted: 4d
# Collected job 54: Principal Software Engineer | Posted: 6d
# Collected job 55: Staff Backend Engineer | Posted: 7d
# Collected job 56: Software Engineer | Posted: 8d
# Collected job 57: Solidity Engineer Smart Contracts Engineer | Posted: 8d
# Collected job 58: Full Stack Engineer | Posted: 16d
# Collected job 59: Staff Software Engineer Metrics US | Posted: 10d
# Collected job 60: Kubernetes Engineer | Posted: 10d
# Scraping page 4: https://remoteok.com/remote-engineer-jobs?page=4
# Collected job 61: Software Engineer | Posted: 1d
# Collected job 62: Senior Software Engineer KSPM | Posted: 1d
# Collected job 63: Software Engineer III | Posted: 1d
# Collected job 64: Back End Developer Winna.com | Posted: 9d
# Collected job 65: Software Engineer Infrastructure | Posted: 2d
# Collected job 66: Software Engineer Data | Posted: 2d
# Collected job 67: Software Engineer III Frontend | Posted: 2d
# Collected job 68: HQ Senior Frontend Engineer | Posted: 2d
# Collected job 69: Software Engineer Microservices | Posted: 2d
# Collected job 70: Senior Fullstack Engineer | Posted: 3d
# Collected job 71: Senior React Full stack Developer | Posted: 3d
# Collected job 72: Technical Product Manager Developer Platform | Posted: 3d
# Collected job 73: DevOps Engineer | Posted: 4d
# Collected job 74: Principal Software Engineer | Posted: 6d
# Collected job 75: Staff Backend Engineer | Posted: 7d
# Collected job 76: Software Engineer | Posted: 8d
# Collected job 77: Solidity Engineer Smart Contracts Engineer | Posted: 8d
# Collected job 78: Full Stack Engineer | Posted: 16d
# Collected job 79: Staff Software Engineer Metrics US | Posted: 10d
# Collected job 80: Kubernetes Engineer | Posted: 10d
# Scraping page 5: https://remoteok.com/remote-engineer-jobs?page=5
# Collected job 81: Software Engineer | Posted: 1d
# Collected job 82: Senior Software Engineer KSPM | Posted: 1d
# Collected job 83: Software Engineer III | Posted: 1d
# Collected job 84: Back End Developer Winna.com | Posted: 9d
# Collected job 85: Software Engineer Infrastructure | Posted: 2d
# Collected job 86: Software Engineer Data | Posted: 2d
# Collected job 87: Software Engineer III Frontend | Posted: 2d
# Collected job 88: HQ Senior Frontend Engineer | Posted: 2d
# Collected job 89: Software Engineer Microservices | Posted: 2d
# Collected job 90: Senior Fullstack Engineer | Posted: 3d
# Collected job 91: Senior React Full stack Developer | Posted: 3d
# Collected job 92: Technical Product Manager Developer Platform | Posted: 3d
# Collected job 93: DevOps Engineer | Posted: 4d
# Collected job 94: Principal Software Engineer | Posted: 6d
# Collected job 95: Staff Backend Engineer | Posted: 7d
# Collected job 96: Software Engineer | Posted: 8d
# Collected job 97: Solidity Engineer Smart Contracts Engineer | Posted: 8d
# Collected job 98: Full Stack Engineer | Posted: 16d
# Collected job 99: Staff Software Engineer Metrics US | Posted: 10d
# Collected job 100: Kubernetes Engineer | Posted: 10d
# Scraping page 6: https://remoteok.com/remote-engineer-jobs?page=6
# Collected job 101: Software Engineer | Posted: 1d
# Collected job 102: Senior Software Engineer KSPM | Posted: 1d
# Collected job 103: Software Engineer III | Posted: 1d
# Collected job 104: Back End Developer Winna.com | Posted: 9d
# Collected job 105: Software Engineer Infrastructure | Posted: 2d
# Collected job 106: Software Engineer Data | Posted: 2d
# Collected job 107: Software Engineer III Frontend | Posted: 2d
# Collected job 108: HQ Senior Frontend Engineer | Posted: 2d
# Collected job 109: Software Engineer Microservices | Posted: 2d
# Collected job 110: Senior Fullstack Engineer | Posted: 3d
# Collected job 111: Senior React Full stack Developer | Posted: 3d
# Collected job 112: Technical Product Manager Developer Platform | Posted: 3d
# Collected job 113: DevOps Engineer | Posted: 4d
# Collected job 114: Principal Software Engineer | Posted: 6d
# Collected job 115: Staff Backend Engineer | Posted: 7d
# Collected job 116: Software Engineer | Posted: 8d
# Collected job 117: Solidity Engineer Smart Contracts Engineer | Posted: 8d
# Collected job 118: Full Stack Engineer | Posted: 16d
# Collected job 119: Staff Software Engineer Metrics US | Posted: 10d
# Collected job 120: Kubernetes Engineer | Posted: 10d
# Scraping page 7: https://remoteok.com/remote-engineer-jobs?page=7
# Collected job 121: Software Engineer | Posted: 1d
# Collected job 122: Senior Software Engineer KSPM | Posted: 1d
# Collected job 123: Software Engineer III | Posted: 1d
# Collected job 124: Back End Developer Winna.com | Posted: 9d
# Collected job 125: Software Engineer Infrastructure | Posted: 2d
# Collected job 126: Software Engineer Data | Posted: 2d
# Collected job 127: Software Engineer III Frontend | Posted: 2d
# Collected job 128: HQ Senior Frontend Engineer | Posted: 2d
# Collected job 129: Software Engineer Microservices | Posted: 2d
# Collected job 130: Senior Fullstack Engineer | Posted: 3d
# Collected job 131: Senior React Full stack Developer | Posted: 3d
# Collected job 132: Technical Product Manager Developer Platform | Posted: 3d
# Collected job 133: DevOps Engineer | Posted: 4d
# Collected job 134: Principal Software Engineer | Posted: 6d
# Collected job 135: Staff Backend Engineer | Posted: 7d
# Collected job 136: Software Engineer | Posted: 8d
# Collected job 137: Solidity Engineer Smart Contracts Engineer | Posted: 8d
# Collected job 138: Full Stack Engineer | Posted: 16d
# Collected job 139: Staff Software Engineer Metrics US | Posted: 10d
# Collected job 140: Kubernetes Engineer | Posted: 10d
# Scraping page 8: https://remoteok.com/remote-engineer-jobs?page=8
# Collected job 141: Software Engineer | Posted: 1d
# Collected job 142: Senior Software Engineer KSPM | Posted: 1d
# Collected job 143: Software Engineer III | Posted: 1d
# Collected job 144: Back End Developer Winna.com | Posted: 9d
# Collected job 145: Software Engineer Infrastructure | Posted: 2d
# Collected job 146: Software Engineer Data | Posted: 2d
# Collected job 147: Software Engineer III Frontend | Posted: 2d
# Collected job 148: HQ Senior Frontend Engineer | Posted: 2d
# Collected job 149: Software Engineer Microservices | Posted: 2d
# Collected job 150: Senior Fullstack Engineer | Posted: 3d
# Collected job 151: Senior React Full stack Developer | Posted: 3d
# Collected job 152: Technical Product Manager Developer Platform | Posted: 3d
# Collected job 153: DevOps Engineer | Posted: 4d
# Collected job 154: Principal Software Engineer | Posted: 6d
# Collected job 155: Staff Backend Engineer | Posted: 7d
# Collected job 156: Software Engineer | Posted: 8d
# Collected job 157: Solidity Engineer Smart Contracts Engineer | Posted: 8d
# Collected job 158: Full Stack Engineer | Posted: 16d
# Collected job 159: Staff Software Engineer Metrics US | Posted: 10d
# Collected job 160: Kubernetes Engineer | Posted: 10d
# Scraping page 9: https://remoteok.com/remote-engineer-jobs?page=9
# Collected job 161: Software Engineer | Posted: 1d
# Collected job 162: Senior Software Engineer KSPM | Posted: 1d
# Collected job 163: Software Engineer III | Posted: 1d
# Collected job 164: Back End Developer Winna.com | Posted: 9d
# Collected job 165: Software Engineer Infrastructure | Posted: 2d
# Collected job 166: Software Engineer Data | Posted: 2d
# Collected job 167: Software Engineer III Frontend | Posted: 2d
# Collected job 168: HQ Senior Frontend Engineer | Posted: 2d
# Collected job 169: Software Engineer Microservices | Posted: 2d
# Collected job 170: Senior Fullstack Engineer | Posted: 3d
# Collected job 171: Senior React Full stack Developer | Posted: 3d
# Collected job 172: Technical Product Manager Developer Platform | Posted: 3d
# Collected job 173: DevOps Engineer | Posted: 4d
# Collected job 174: Principal Software Engineer | Posted: 6d
# Collected job 175: Staff Backend Engineer | Posted: 7d
# Collected job 176: Software Engineer | Posted: 8d
# Collected job 177: Solidity Engineer Smart Contracts Engineer | Posted: 8d
# Collected job 178: Full Stack Engineer | Posted: 16d
# Collected job 179: Staff Software Engineer Metrics US | Posted: 10d
# Collected job 180: Kubernetes Engineer | Posted: 10d
# Scraping page 10: https://remoteok.com/remote-engineer-jobs?page=10
# Collected job 181: Software Engineer | Posted: 1d
# Collected job 182: Senior Software Engineer KSPM | Posted: 1d
# Collected job 183: Software Engineer III | Posted: 1d
# Collected job 184: Back End Developer Winna.com | Posted: 9d
# Collected job 185: Software Engineer Infrastructure | Posted: 2d
# Collected job 186: Software Engineer Data | Posted: 2d
# Collected job 187: Software Engineer III Frontend | Posted: 2d
# Collected job 188: HQ Senior Frontend Engineer | Posted: 2d
# Collected job 189: Software Engineer Microservices | Posted: 2d
# Collected job 190: Senior Fullstack Engineer | Posted: 3d
# Collected job 191: Senior React Full stack Developer | Posted: 3d
# Collected job 192: Technical Product Manager Developer Platform | Posted: 3d
# Collected job 193: DevOps Engineer | Posted: 4d
# Collected job 194: Principal Software Engineer | Posted: 6d
# Collected job 195: Staff Backend Engineer | Posted: 7d
# Collected job 196: Software Engineer | Posted: 8d
# Collected job 197: Solidity Engineer Smart Contracts Engineer | Posted: 8d
# Collected job 198: Full Stack Engineer | Posted: 16d
# Collected job 199: Staff Software Engineer Metrics US | Posted: 10d
# Collected job 200: Kubernetes Engineer | Posted: 10d
#
# Successfully saved 200 jobs to remote_jobs.csv

# %%
df=pd.read_csv("remote_jobs.csv")

# %%
import re
# Clean columns using regex
df["location"] = df["location"].str.replace(r"^[^a-zA-Z]+", "", regex=True)
df
# Out:
#                                           title             company  \
# 0                             Software Engineer              Upvest
# 1                 Senior Software Engineer KSPM             Cast AI
# 2                         Software Engineer III          Jack Henry
# 3                  Back End Developer Winna.com               Winna
# 4              Software Engineer Infrastructure            Gauntlet
# ..                                          ...                 ...
# 195                           Software Engineer           Serotonin
# 196  Solidity Engineer Smart Contracts Engineer            Sei Labs
# 197                         Full Stack Engineer             Stealth
# 198          Staff Software Engineer Metrics US    Weights & Biases
# 199                         Kubernetes Engineer  00100 LEIDOS, INC.
#
#                  location           salary date_posted
# 0      Probably worldwide  💰 $70k - $120k*          1d
# 1      Probably worldwide  💰 $70k - $120k*          1d
# 2      Probably worldwide  💰 $55k - $100k*          1d
# 3               Worldwide    💰 $40k - $80k          9d
# 4               Worldwide   💰 $60k - $80k*          2d
# ..                    ...              ...         ...
# 195    Probably worldwide  💰 $70k - $120k*          8d
# 196    Probably worldwide  💰 $55k - $100k*          8d
# 197            Contractor   💰 $60k - $180k         16d
# 198         United States   💰 $60k - $80k*         10d
# 199  Remote/Teleworker US   💰 $60k - $80k*         10d
#
# [200 rows x 5 columns]

# %%
def clean_salary(s):
    s = re.sub(r"[^\d\skK\-\$]", "", s)
    matches = re.findall(r"(\d+)[kK]", s)
    if len(matches) == 2:
        low = int(matches[0]) * 1000
        high = int(matches[1]) * 1000
        return f"{low}${'-'}{high}$"
    return None

df["cleaned_salary"] = df["salary"].apply(clean_salary)
df
# Out:
#                                           title             company  \
# 0                             Software Engineer              Upvest
# 1                 Senior Software Engineer KSPM             Cast AI
# 2                         Software Engineer III          Jack Henry
# 3                  Back End Developer Winna.com               Winna
# 4              Software Engineer Infrastructure            Gauntlet
# ..                                          ...                 ...
# 195                           Software Engineer           Serotonin
# 196  Solidity Engineer Smart Contracts Engineer            Sei Labs
# 197                         Full Stack Engineer             Stealth
# 198          Staff Software Engineer Metrics US    Weights & Biases
# 199                         Kubernetes Engineer  00100 LEIDOS, INC.
#
#                  location           salary date_posted  cleaned_salary
# 0      Probably worldwide  💰 $70k - $120k*          1d  70000$-120000$
# 1      Probably worldwide  💰 $70k - $120k*          1d  70000$-120000$
# 2      Probably worldwide  💰 $55k - $100k*          1d  55000$-100000$
# 3               Worldwide    💰 $40k - $80k          9d   40000$-80000$
# 4               Worldwide   💰 $60k - $80k*          2d   60000$-80000$
# ..                    ...              ...         ...             ...
# 195    Probably worldwide  💰 $70k - $120k*          8d  70000$-120000$
# 196    Probably worldwide  💰 $55k - $100k*          8d  55000$-100000$
# 197            Contractor   💰 $60k - $180k         16d  60000$-180000$
# 198         United States   💰 $60k - $80k*         10d   60000$-80000$
# 199  Remote/Teleworker US   💰 $60k - $80k*         10d   60000$-80000$
#
# [200 rows x 6 columns]

# %%
df = df.drop("salary", axis=1)

# %%
df
# Out:
#                                           title             company  \
# 0                             Software Engineer              Upvest
# 1                 Senior Software Engineer KSPM             Cast AI
# 2                         Software Engineer III          Jack Henry
# 3                  Back End Developer Winna.com               Winna
# 4              Software Engineer Infrastructure            Gauntlet
# ..                                          ...                 ...
# 195                           Software Engineer           Serotonin
# 196  Solidity Engineer Smart Contracts Engineer            Sei Labs
# 197                         Full Stack Engineer             Stealth
# 198          Staff Software Engineer Metrics US    Weights & Biases
# 199                         Kubernetes Engineer  00100 LEIDOS, INC.
#
#                  location date_posted  cleaned_salary
# 0      Probably worldwide          1d  70000$-120000$
# 1      Probably worldwide          1d  70000$-120000$
# 2      Probably worldwide          1d  55000$-100000$
# 3               Worldwide          9d   40000$-80000$
# 4               Worldwide          2d   60000$-80000$
# ..                    ...         ...             ...
# 195    Probably worldwide          8d  70000$-120000$
# 196    Probably worldwide          8d  55000$-100000$
# 197            Contractor         16d  60000$-180000$
# 198         United States         10d   60000$-80000$
# 199  Remote/Teleworker US         10d   60000$-80000$
#
# [200 rows x 5 columns]

# %%
df = df.rename(columns={"cleaned_salary": "Salary in $"})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        200 non-null    object
#  1   company      200 non-null    object
#  2   location     200 non-null    object
#  3   date_posted  200 non-null    object
#  4   Salary in $  200 non-null    object
# dtypes: object(5)
# memory usage: 7.9+ KB

# %%
from datetime import datetime, timedelta

today = datetime.today()

def convert_to_date(x):
     days = int(x.replace("d", ""))
     return (today - timedelta(days=days)).strftime('%Y-%m-%d')

# Apply conversion
df["Posted_date"] = df["date_posted"].apply(convert_to_date)

df
# Out:
#                                           title             company  \
# 0                             Software Engineer              Upvest
# 1                 Senior Software Engineer KSPM             Cast AI
# 2                         Software Engineer III          Jack Henry
# 3                  Back End Developer Winna.com               Winna
# 4              Software Engineer Infrastructure            Gauntlet
# ..                                          ...                 ...
# 195                           Software Engineer           Serotonin
# 196  Solidity Engineer Smart Contracts Engineer            Sei Labs
# 197                         Full Stack Engineer             Stealth
# 198          Staff Software Engineer Metrics US    Weights & Biases
# 199                         Kubernetes Engineer  00100 LEIDOS, INC.
#
#                  location date_posted     Salary in $ Posted_date
# 0      Probably worldwide          1d  70000$-120000$  2025-04-24
# 1      Probably worldwide          1d  70000$-120000$  2025-04-24
# 2      Probably worldwide          1d  55000$-100000$  2025-04-24
# 3               Worldwide          9d   40000$-80000$  2025-04-16
# 4               Worldwide          2d   60000$-80000$  2025-04-23
# ..                    ...         ...             ...         ...
# 195    Probably worldwide          8d  70000$-120000$  2025-04-17
# 196    Probably worldwide          8d  55000$-100000$  2025-04-17
# 197            Contractor         16d  60000$-180000$  2025-04-09
# 198         United States         10d   60000$-80000$  2025-04-15
# 199  Remote/Teleworker US         10d   60000$-80000$  2025-04-15
#
# [200 rows x 6 columns]

# %%
df = df.drop("date_posted", axis=1)

# %%
df
# Out:
#                                           title             company  \
# 0                             Software Engineer              Upvest
# 1                 Senior Software Engineer KSPM             Cast AI
# 2                         Software Engineer III          Jack Henry
# 3                  Back End Developer Winna.com               Winna
# 4              Software Engineer Infrastructure            Gauntlet
# ..                                          ...                 ...
# 195                           Software Engineer           Serotonin
# 196  Solidity Engineer Smart Contracts Engineer            Sei Labs
# 197                         Full Stack Engineer             Stealth
# 198          Staff Software Engineer Metrics US    Weights & Biases
# 199                         Kubernetes Engineer  00100 LEIDOS, INC.
#
#                  location     Salary in $ Posted_date
# 0      Probably worldwide  70000$-120000$  2025-04-24
# 1      Probably worldwide  70000$-120000$  2025-04-24
# 2      Probably worldwide  55000$-100000$  2025-04-24
# 3               Worldwide   40000$-80000$  2025-04-16
# 4               Worldwide   60000$-80000$  2025-04-23
# ..                    ...             ...         ...
# 195    Probably worldwide  70000$-120000$  2025-04-17
# 196    Probably worldwide  55000$-100000$  2025-04-17
# 197            Contractor  60000$-180000$  2025-04-09
# 198         United States   60000$-80000$  2025-04-15
# 199  Remote/Teleworker US   60000$-80000$  2025-04-15
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        200 non-null    object
#  1   company      200 non-null    object
#  2   location     200 non-null    object
#  3   Salary in $  200 non-null    object
#  4   Posted_date  200 non-null    object
# dtypes: object(5)
# memory usage: 7.9+ KB

# %%
df["Posted_date"] = pd.to_datetime(df["Posted_date"])

# %%
df['Salary in $'].unique()
# Out:
# array(['70000$-120000$', '55000$-100000$', '40000$-80000$',
#        '60000$-80000$', '75000$-120000$', '63000$-85000$',
#        '68000$-98000$', '60000$-230000$', '63000$-88000$',
#        '65000$-85000$', '65000$-120000$', '70000$-90000$',
#        '60000$-180000$'], dtype=object)

# %%
df["Salary in $"] = df["Salary in $"].str.replace("$", "", regex=False)

# %%
df
# Out:
#                                           title             company  \
# 0                             Software Engineer              Upvest
# 1                 Senior Software Engineer KSPM             Cast AI
# 2                         Software Engineer III          Jack Henry
# 3                  Back End Developer Winna.com               Winna
# 4              Software Engineer Infrastructure            Gauntlet
# ..                                          ...                 ...
# 195                           Software Engineer           Serotonin
# 196  Solidity Engineer Smart Contracts Engineer            Sei Labs
# 197                         Full Stack Engineer             Stealth
# 198          Staff Software Engineer Metrics US    Weights & Biases
# 199                         Kubernetes Engineer  00100 LEIDOS, INC.
#
#                  location   Salary in $ Posted_date
# 0      Probably worldwide  70000-120000  2025-04-24
# 1      Probably worldwide  70000-120000  2025-04-24
# 2      Probably worldwide  55000-100000  2025-04-24
# 3               Worldwide   40000-80000  2025-04-16
# 4               Worldwide   60000-80000  2025-04-23
# ..                    ...           ...         ...
# 195    Probably worldwide  70000-120000  2025-04-17
# 196    Probably worldwide  55000-100000  2025-04-17
# 197            Contractor  60000-180000  2025-04-09
# 198         United States   60000-80000  2025-04-15
# 199  Remote/Teleworker US   60000-80000  2025-04-15
#
# [200 rows x 5 columns]

# %%
def get_mean_salary(s):
    low, high = map(int, s.split('-'))
    return (low + high) / 2

df["expected_salary"] = df["Salary in $"].apply(get_mean_salary)

# %%
df
# Out:
#                                           title             company  \
# 0                             Software Engineer              Upvest
# 1                 Senior Software Engineer KSPM             Cast AI
# 2                         Software Engineer III          Jack Henry
# 3                  Back End Developer Winna.com               Winna
# 4              Software Engineer Infrastructure            Gauntlet
# ..                                          ...                 ...
# 195                           Software Engineer           Serotonin
# 196  Solidity Engineer Smart Contracts Engineer            Sei Labs
# 197                         Full Stack Engineer             Stealth
# 198          Staff Software Engineer Metrics US    Weights & Biases
# 199                         Kubernetes Engineer  00100 LEIDOS, INC.
#
#                  location   Salary in $ Posted_date  expected_salary
# 0      Probably worldwide  70000-120000  2025-04-24          95000.0
# 1      Probably worldwide  70000-120000  2025-04-24          95000.0
# 2      Probably worldwide  55000-100000  2025-04-24          77500.0
# 3               Worldwide   40000-80000  2025-04-16          60000.0
# 4               Worldwide   60000-80000  2025-04-23          70000.0
# ..                    ...           ...         ...              ...
# 195    Probably worldwide  70000-120000  2025-04-17          95000.0
# 196    Probably worldwide  55000-100000  2025-04-17          77500.0
# 197            Contractor  60000-180000  2025-04-09         120000.0
# 198         United States   60000-80000  2025-04-15          70000.0
# 199  Remote/Teleworker US   60000-80000  2025-04-15          70000.0
#
# [200 rows x 6 columns]

# %%
df[["min_salary", "max_salary"]] = df["Salary in $"].str.split('-', expand=True).astype(int)
df
# Out:
#                                           title             company  \
# 0                             Software Engineer              Upvest
# 1                 Senior Software Engineer KSPM             Cast AI
# 2                         Software Engineer III          Jack Henry
# 3                  Back End Developer Winna.com               Winna
# 4              Software Engineer Infrastructure            Gauntlet
# ..                                          ...                 ...
# 195                           Software Engineer           Serotonin
# 196  Solidity Engineer Smart Contracts Engineer            Sei Labs
# 197                         Full Stack Engineer             Stealth
# 198          Staff Software Engineer Metrics US    Weights & Biases
# 199                         Kubernetes Engineer  00100 LEIDOS, INC.
#
#                  location   Salary in $ Posted_date  expected_salary  \
# 0      Probably worldwide  70000-120000  2025-04-24          95000.0
# 1      Probably worldwide  70000-120000  2025-04-24          95000.0
# 2      Probably worldwide  55000-100000  2025-04-24          77500.0
# 3               Worldwide   40000-80000  2025-04-16          60000.0
# 4               Worldwide   60000-80000  2025-04-23          70000.0
# ..                    ...           ...         ...              ...
# 195    Probably worldwide  70000-120000  2025-04-17          95000.0
# 196    Probably worldwide  55000-100000  2025-04-17          77500.0
# 197            Contractor  60000-180000  2025-04-09         120000.0
# 198         United States   60000-80000  2025-04-15          70000.0
# 199  Remote/Teleworker US   60000-80000  2025-04-15          70000.0
#
#      min_salary  max_salary
# 0         70000      120000
# 1         70000      120000
# 2         55000      100000
# 3         40000       80000
# 4         60000       80000
# ..          ...         ...
# 195       70000      120000
# 196       55000      100000
# 197       60000      180000
# 198       60000       80000
# 199       60000       80000
#
# [200 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            200 non-null    object
#  1   company          200 non-null    object
#  2   location         200 non-null    object
#  3   Salary in $      200 non-null    object
#  4   Posted_date      200 non-null    datetime64[ns]
#  5   expected_salary  200 non-null    float64
#  6   min_salary       200 non-null    int32
#  7   max_salary       200 non-null    int32
# dtypes: datetime64[ns](1), float64(1), int32(2), object(4)
# memory usage: 11.1+ KB

# %%
df.to_csv("remote_jobs_clean.csv", index=False, encoding='utf-8')
